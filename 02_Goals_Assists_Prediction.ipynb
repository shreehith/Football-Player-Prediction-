# %%
# Player Performance Prediction - Objective 2
## Predicting Goals and Assists in Upcoming Matches

**Goal**: Predict how many goals and assists a player will have in upcoming matches

**Key Features to Use**:
- Historical goals and assists data
- Shot creation and expected goals (xG)
- Key passes and assists per game
- Playing time and position
- Recent form and trends
- Opposition strength

**Models to Implement**:
- Poisson Regression (for count data)
- Random Forest Regressor
- Gradient Boosting
- Neural Networks

**Output**: 
- Expected goals per match
- Expected assists per match
- Confidence intervals
